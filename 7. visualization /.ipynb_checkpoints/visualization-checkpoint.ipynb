# %%
from skimage import io
img = io.imread('../sample/1.tiff')
io.imshow(img)

# %%
from matplotlib import pyplot as plt
plt.imshow(img)

# %%
plt.imshow(img, cmap="hot")

# %%
plt.imshow(img, cmap="Blues")

# %%
fig = plt.figure(figsize=(10, 10))

ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img, cmap="hot")
ax1.title.set_text("1st")

ax2 = fig.add_subplot(2,2,2)
ax2.imshow(img, cmap="jet")
ax2.title.set_text("2nd")

ax3 = fig.add_subplot(2,2,3)
ax3.imshow(img, cmap="gray")
ax3.title.set_text("3rd")

ax4 = fig.add_subplot(2,2,4)
ax4.imshow(img, cmap="nipy_spectral")
ax4.title.set_text("4th")

plt.show()

# %%
''' Has issue on mac! it will freeze 
import cv2

gray_img = cv2.imread('../sample/1.tiff', 0)
color_img = cv2.imread('../sample/1.tiff', 1)

cv2.imshow("pic from skimage import", img)
cv2.imshow("color pic from opencv import", color_img)
cv2.imshow("gray pic from opencv import", gray_img)


cv2.waitKey(0)
cv2.destroyAllWindows()
'''
# Out:
# ' Has issue on mac! it will freeze \nimport cv2\n\ngray_img = cv2.imread(\'../sample/1.tiff\', 0)\ncolor_img = cv2.imread(\'../sample/1.tiff\', 1)\n\ncv2.imshow("pic from skimage import", img)\ncv2.imshow("color pic from opencv import", color_img)\ncv2.imshow("gray pic from opencv import", gray_img)\n\n\ncv2.waitKey(0)\ncv2.destroyAllWindows()\n'
